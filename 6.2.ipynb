# %% [raw]
# write a pager program, your solution should crompt for a file name and display the text file 5 lines at a time, pausing each time to ask user to press any key to continue and 'q' to quit

# %%
filename = open(input("Enter the filename: "))
lines=5
for i,l in enumerate(filename,1):
    print(i,":",l)
    if i%lines==0:
        x=input("Press any key to continue or 'q' to quit")
        if x=='q' or x=='Q':
            break
        else:
            continue
# Out:
# Enter the filename: example.txt
# 1 : Apple is a fruit which is healthy
#
# 2 : Greenapple is tasty and sweet
#
# 3 : Oranges and bananas are good for health
#
# 4 : Fruits are a good source of vitamins
#
# 5 : Friends are crazy, Friends are naughty !
#
# Press any key to continue or 'q' to quitf
# 6 : Friends are honest, Friends are best !
#
# 7 : Friends are like keygen, friends are like license key !
#
# 8 : We are nothing without friends, Life is not possible without friends !
#
# 9 : hello
#
# 10 : hi
#
# Press any key to continue or 'q' to quit3
# 11 : this
#
# 12 : is
#
# 13 : python
#
# 14 : ch 6

# %% [markdown]
# **Write a program to compare two text files. If they are different, give the line and column numbers in the files where the  difference occurs.**

# %%
f1 = open('p1.txt')
f2 = open('p2.txt')
r1 = f1.read()
r2 = f2.read()
c=l=1
for i in range(len(r1)):
    if r1[i]==r[i]:
        c=c+1
        if r[i]=='\n':
            l=l+1
            c=1
    else:
        print("line : ",l," position : ",c)
        c=c+1
f1.close()
f2.close()
# Out:
# line :  1  position :  7
# line :  2  position :  6
# line :  2  position :  9
# line :  3  position :  3
# line :  3  position :  4

# %%
f=open("p2.txt")
d=open("p3.txt",'w')
while True:
    b=f.readline()
    if len(b)!=0:
        if b[0]=='#':
            continue
        else:
            if '#' in b:
                for index in range(1,len(b)):
                    if b[index]=='#':
                        d.write(b[0:index]+'\n')
            else:
                d.write(b)
    else:
        break
                
f.close()
d.close()

# %% [markdown]
# **wap to search for a string in a text file**

# %%
f=open("p2.txt")
word=input("Enter the word you want to search for : ")
r=f.read()
i=r.find(word)
if i==-1:
    print("not found")
else:
    print("position",i)
f.close()
# Out:
# Enter the word you want to search for : I
# position 25

# %% [markdown]
# wap to extract all 4 letter words that start and end with same letter from a given text file

# %%
f=open("n.txt")
r=f.read().split()
for i in r:
    if len(i)==4 and i[0]==i[-1]:
        print(i)
# Out:
# test
# area
# text

# %%
#476
f1=open("p1.txt")
f2=open("p2.txt",'w')
f3=open("p3.txt",'w')
r1=f1.read()[::-1]
f2.write(r1)
l=0
while l!=2:
# Out:
# 33
